# %%
import sys
print("Python executable:", sys.executable)
# Out:
# Python executable: /Users/baloyithabangbonganijunior/Library/CloudStorage/OneDrive-UniversityofCapeTown/ACADEMICS FOLDER/WORK PROJECTS/Advanced Quantitative Engineering & AI Portfolio/01-Finance/.venv/bin/python

# %%
import sys
path = sys.executable.replace(" ", "\\ ").replace("&", "\\&")
print("Escaped:", path)
# !{path} -m pip install yfinance pandas numpy
# Out:
# Escaped: /Users/baloyithabangbonganijunior/Library/CloudStorage/OneDrive-UniversityofCapeTown/ACADEMICS\ FOLDER/WORK\ PROJECTS/Advanced\ Quantitative\ Engineering\ \&\ AI\ Portfolio/01-Finance/.venv/bin/python
# zsh:1: no such file or directory: /Users/baloyithabangbonganijunior/Library/CloudStorage/OneDrive-UniversityofCapeTown/ACADEMICS FOLDER/WORK PROJECTS/Advanced Quantitative Engineering & AI Portfolio/01-Finance/.venv/bin/python

# %%
import yfinance as yf
import pandas as pd
from pathlib import Path

tickers = ["AAPL", "MSFT", "JPM", "XOM"]
data = yf.download(tickers, start="2020-01-01", end="2025-01-01")

data = data["Adj Close"].reset_index()
data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'yfinance'
