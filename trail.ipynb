# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("/Users/baloyithabangbonganijunior/Downloads/trial.csv")

# Save as Excel file
df.to_excel("data.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 7
#       4 df = pd.read_csv("/Users/baloyithabangbonganijunior/Downloads/trial.csv")
#       6 # Save as Excel file
# ----> 7 df.to_excel("data.xlsx", index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
